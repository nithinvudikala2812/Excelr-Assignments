# %% [markdown]
# #Basics of Python
# #Coding Exercises

# %% [markdown]
# Exercise 1: Prime Numbers

# %%
#taking any number as input for n
n=int(input())
if n==0 or n==1:
  print("not a prime number")
elif n>1:
  #check for two factors
  for i in range(2,n):
    if n%i==0:
      print("not a prime number")
      #break out of the loop
      break
  else:
    print("prime number")
# Out:
# 0
# not a prime number

# %% [markdown]
# Exercise 2: Product of Random Numbers

# %%
#importing random function
import random

#generating two random integers
n1=random.randint(1,100)
n2=random.randint(1,100)

#multiplying those generated random integers
product=n1*n2

#printing the result
print("Product of two random integers is:",product)
# Out:
# Product of two random integers is: 868

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers

# %%
#squares of all even numbers ranging from 100 to 200
for i in range(100,201,2):
  print(i**2)
# Out:
# 10000
# 10404
# 10816
# 11236
# 11664
# 12100
# 12544
# 12996
# 13456
# 13924
# 14400
# 14884
# 15376
# 15876
# 16384
# 16900
# 17424
# 17956
# 18496
# 19044
# 19600
# 20164
# 20736
# 21316
# 21904
# 22500
# 23104
# 23716
# 24336
# 24964
# 25600
# 26244
# 26896
# 27556
# 28224
# 28900
# 29584
# 30276
# 30976
# 31684
# 32400
# 33124
# 33856
# 34596
# 35344
# 36100
# 36864
# 37636
# 38416
# 39204
# 40000

# %% [markdown]
# Exercise 4: Word counter

# %%
#input text
text = "This is a sample text."

#spliting the text
word_list = text.split()

#counting the words using len function

word_count = len(word_list)
print("The number of words in the text is:", word_count)
# Out:
# The number of words in the text is: 5

# %% [markdown]
# Exercise 5: Check for Palindrome

# %%
def ispalindrome(text):
    """Checks if a given string is a palindrome."""
    # Remove spaces and convert to lowercase for case-insensitive comparison
    cleaned_text = "".join(text.split()).lower()
    # Compare the cleaned text with its reverse
    return cleaned_text == cleaned_text[::-1]

# Example usage:
word1 = "racecar"
word2 = "hello"

if ispalindrome(word1):
    print(f"'{word1}' is a palindrome.")
else:
    print(f"'{word1}' is not a palindrome.")

if ispalindrome(word2):
    print(f"'{word2}' is a palindrome.")
else:
    print(f"'{word2}' is not a palindrome.")
# Out:
# 'racecar' is a palindrome.
# 'hello' is not a palindrome.
